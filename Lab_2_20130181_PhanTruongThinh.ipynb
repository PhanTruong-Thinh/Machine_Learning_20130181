# %% [markdown]
# # Lab #2
# This lab is the first step to get farmilliar with some common Machine Learning libraries, named ***Pandas*** and ***Matlotlib***.
#
# *   **Deadline: 23:59, 27/02/2023**

# %% [markdown]
# #0. Mount Drive

# %%
from google.colab import drive
drive.mount('/content/gdrive')
# %cd '/content/gdrive/MyDrive/ML'
# Out:
# Drive already mounted at /content/gdrive; to attempt to forcibly remount, call drive.mount("/content/gdrive", force_remount=True).
# /content/gdrive/MyDrive/ML

# %% [markdown]
# #1. Import libraries

# %%
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd

# %% [markdown]
# #2. Load dataset
#
# *   Load dataset (named ***shopping-data.csv***) using ***read_csv*** from pandas
# *   Then, display 10 last examples

# %%
table= pd.read_csv("shopping-data.csv")
table.tail(10)
# Out:
#      CustomerID   Genre  Age  Annual Income (k$)  Spending Score (1-100)
# 190         191  Female   34                 103                      23
# 191         192  Female   32                 103                      69
# 192         193    Male   33                 113                       8
# 193         194  Female   38                 113                      91
# 194         195  Female   47                 120                      16
# 195         196  Female   35                 120                      79
# 196         197  Female   45                 126                      28
# 197         198    Male   32                 126                      74
# 198         199    Male   32                 137                      18
# 199         200    Male   30                 137                      83

# %% [markdown]
# #3. Show statistics of the given dataset

# %%
table.describe()
# Out:
#        CustomerID         Age  Annual Income (k$)  Spending Score (1-100)
# count  200.000000  200.000000          200.000000              200.000000
# mean   100.500000   38.850000           60.560000               50.200000
# std     57.879185   13.969007           26.264721               25.823522
# min      1.000000   18.000000           15.000000                1.000000
# 25%     50.750000   28.750000           41.500000               34.750000
# 50%    100.500000   36.000000           61.500000               50.000000
# 75%    150.250000   49.000000           78.000000               73.000000
# max    200.000000   70.000000          137.000000               99.000000

# %% [markdown]
# #4. Sort dataset by ***Age***

# %%
table.sort_values(by="Age", ascending="true")
# Out:
#      CustomerID   Genre  Age  Annual Income (k$)  Spending Score (1-100)
# 114         115  Female   18                  65                      48
# 91           92    Male   18                  59                      41
# 65           66    Male   18                  48                      59
# 33           34    Male   18                  33                      92
# 0             1    Male   19                  15                      39
# ..          ...     ...  ...                 ...                     ...
# 90           91  Female   68                  59                      55
# 108         109    Male   68                  63                      43
# 57           58    Male   69                  44                      46
# 70           71    Male   70                  49                      55
# 60           61    Male   70                  46                      56
#
# [200 rows x 5 columns]

# %% [markdown]
# #5. Group dataset by ***Gender*** and ***Age***

# %%
table.groupby(['Genre', 'Age']).groups
table
# Out:
#      CustomerID   Genre  Age  Annual Income (k$)  Spending Score (1-100)
# 0             1    Male   19                  15                      39
# 1             2    Male   21                  15                      81
# 2             3  Female   20                  16                       6
# 3             4  Female   23                  16                      77
# 4             5  Female   31                  17                      40
# ..          ...     ...  ...                 ...                     ...
# 195         196  Female   35                 120                      79
# 196         197  Female   45                 126                      28
# 197         198    Male   32                 126                      74
# 198         199    Male   32                 137                      18
# 199         200    Male   30                 137                      83
#
# [200 rows x 5 columns]

# %% [markdown]
# #6. Use scatter plot to represent the relationship between ***Age*** and ***Annual Income***
# Rememer adding titles, xlabel, ylabel, ... to the plot

# %%
plt.scatter(table['Age'], table['Annual Income (k$)'])
plt.title("the relationship between Age and Annual Income")
plt.xlabel("Age")
plt.ylabel("Annual Income (k$)")
plt.legend()
plt.show()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-50-9bca3b5b9f62> in <module>
#       1 plt.scatter(table['Age'], table['Annual Income (k$)'])
#       2 plt.title("the relationship between Age and Annual Income")
# ----> 3 plt.xlabel("Age")
#       4 plt.ylabel("Annual Income (k$)")
#       5 plt.legend()
#
# TypeError: 'str' object is not callable

# %% [markdown]
# #7. Use histogram plot to represent the distribution of ***Age***

# %%
my_xlabel = "Age"
plt.hist(table['Age'], rwidth=0.8)
plt.xlabel(my_xlabel)
plt.show()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-54-4c1cf28a12cd> in <module>
#       1 my_xlabel = "Age"
#       2 plt.hist(table['Age'], rwidth=0.8)
# ----> 3 plt.xlabel(my_xlabel)
#       4 plt.show()
#
# TypeError: 'str' object is not callable

# %% [markdown]
# #8. Finally,
# Save a copy in your Github. Remember renaming the notebook.
